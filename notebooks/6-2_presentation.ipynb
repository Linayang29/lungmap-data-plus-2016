# %%
# Image labeled with SOX9_SFTPC_ACTA2

# %%
from skimage import img_as_float
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from skimage.external import tifffile
# %matplotlib inline

# %%
# # 20X from E16.5
image = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-04-029_20X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif')

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
plt.figure(figsize=(14, 9))
plt.imshow(image)
pass

# %%
img16_5_1 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_001.tif')
img16_5_2 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_002.tif')
img16_5_3 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif')
img16_5_4 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_004.tif')

# %%
# 60X from E16.5
fig, axes = plt.subplots(1, 4, figsize=(14, 4), sharex=True, sharey=True,
                         subplot_kw={'adjustable': 'box-forced'})
axes[0].imshow(img16_5_1)
axes[1].imshow(img16_5_2)
axes[2].imshow(img16_5_3)
axes[3].imshow(img16_5_4)
plt.tight_layout()
pass

# %%
image = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-004-030_20X_C57BL6_E18.5_LMM.14.27.6.53_SOX9_SFTPC_ACTA2_004.tif')
plt.figure(figsize=(14, 9))
plt.imshow(image)
pass

# %%
# 60X from E18.5
img18_5_1 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-004-030_60X_C57BL6_E18.5_LMM.14.27.6.53_SOX9_SFTPC_ACTA2_001.tif')
img18_5_2 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-004-030_60X_C57BL6_E18.5_LMM.14.27.6.53_SOX9_SFTPC_ACTA2_001.tif')
img18_5_3 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-004-030_60X_C57BL6_E18.5_LMM.14.27.6.53_SOX9_SFTPC_ACTA2_001.tif')
img18_5_4 = tifffile.imread('G:\\2016\\Summer\\LungMAP\\Image_data\\E16.5\\2015-004-030_60X_C57BL6_E18.5_LMM.14.27.6.53_SOX9_SFTPC_ACTA2_001.tif')

# %%
fig, axes = plt.subplots(1, 4, figsize=(14, 4), sharex=True, sharey=True,
                         subplot_kw={'adjustable': 'box-forced'})
axes[0].imshow(img18_5_1)
axes[1].imshow(img18_5_2)
axes[2].imshow(img18_5_3)
axes[3].imshow(img18_5_4)
plt.tight_layout()
pass
