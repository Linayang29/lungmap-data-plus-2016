# %%
# Outline:

# Variables
# Data types
# Basic operators
# If statements
# While, for loops
# User defined functions
# Objects and Classes
# Modules

# %%
# Variables:

# Python variables do not need explicit declaration to reserve memory space. 

# The declaration happens automatically when we assign a value to a variable.


# Variables name rules:

# Variables names must start with a letter or an underscore

# The remainder of the variable name may consist of letters, numbers and underscores.

a123=5
A123=6
_ab_, c, de = 1, 2, "john"     #Multiple assignment

print(a123, A123, _ab_, c, de)
# Out:
# 5 6 1 2 john

# %%
# Python has five standard data types − Numbers, String, List, Tuple, Dictionary

# String
str = 'Hello'

print (str)          # Prints complete string
print (str[0])       # Prints first character of the string
print (str[-4])      # Prints 4th character from the end
print (str[1:3])     # Prints characters starting from 2nd to 3th
print (str[2:])      # Prints string starting from 3rd character
print (str * 2)      # Prints string two times
print (str + "TEST") # Prints concatenated string
# Out:
# Hello
# H
# e
# el
# llo
# HelloHello
# HelloTEST

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Lina\\Desktop\\Hello.PNG")

# %%
# List
x = [1,2,3, "apple"]
print (x[2])


# Tuple
#"read-only" list
tuple = ( 'abcd', 786 , 2.23, 'john', 70.2  )
list = [ 'abcd', 786 , 2.23, 'john', 70.2  ]
#tuple[2] = 1000    # Invalid syntax with tuple
list[2] = 1000     # Valid syntax with list


# Dictionary
# Contains "key-value" pairs

dict = {'name': 'john','code':6734, 'dept': 'sales'}

print (dict.keys())
print (dict.values())
# Out:
# 3
# dict_keys(['name', 'code', 'dept'])
# dict_values(['john', 6734, 'sales'])

# %%
# Basic operators
from IPython.display import Image
Image(filename="C:\\Users\\Lina\\Desktop\\operator.PNG")

# %%
# If statement:

for i in range(1,100):    
    if i%3==0 and i%5!=0: x="Fizz"
    elif i%3!=0 and i%5==0: x="Buzz"
    elif i%3==0 and i%5==0: x="Fizz Buzz"
    else: x=i
    print(i,x)
    
# Python uses indentation instead of braces to determine the scope of expressions
# All lines must be indented the same amount to be part of the scope (or indented more if part of an inner scope

# %%
# While Loop:
x = 1
while x < 10 :
    print (x)
    x = x + 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# For loop
for j in range(1,5):
    print (j)
    
for j in range(5):
    print (j)
# Out:
# 1
# 2
# 3
# 4
# 0
# 1
# 2
# 3
# 4

# %%
# break and continue:

# The break statement breaks out of the smallest enclosing for or while loop.

for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print (n, 'equals', x, '*', n/x)
            break
    else:
        print (n, 'is a prime number')

# The continue statement continues with the next iteration of the loop

for num in range(2, 10):
    if num % 2 == 0:
        print ("Found an even number", num)
        continue
    print ("Found an odd number", num)
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 equals 2 * 2.0
# 5 is a prime number
# 6 equals 2 * 3.0
# 7 is a prime number
# 8 equals 2 * 4.0
# 9 equals 3 * 3.0
# Found an even number 2
# Found an odd number 3
# Found an even number 4
# Found an odd number 5
# Found an even number 6
# Found an odd number 7
# Found an even number 8
# Found an odd number 9

# %%
# Functions
def max(x,y) :
    if x < y :
        return y
    else :
        return x

max_num = max(2,6)     # call function
print ("max number is %d" %max_num)

# Function can be a parameter
def foo(f, a) :
    return f(a)
def bar(p) :
    return p * p
    print(p)

foo(bar,3)

print(p)  #local variables can be accessed only inside the function in which they are declared
# Out:
# max number is 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-01784b19c326> in <module>()
#      18 foo(bar,3)
#      19
# ---> 20 print(p)  #local variables can be accessed only inside the function in which they are declared
#
# NameError: name 'p' is not defined

# %%
#Class

# A class is a way to take a grouping of functions and data and place them inside a container
# so you can access them with the . (dot) operator.

class MyClass(object): 
    i = 12345 
    def f(self): 
        return self.i 

MyClass.i
MyClass.f
# Out:
# <function __main__.MyClass.f>

# %%
# Modules
# a module is a file consisting of Python code.
import math
dir(math)
# math.pi
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'hypot',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'pi',
#  'pow',
#  'radians',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'trunc']

# %%
from math import pi
print (pi)

from math import *
